# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhid707/stock_pair/blob/master/live_spread_pairs_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install arch
# Out:
# ...
#      |████████████████████████████████| 798kB 5.4MB/s
# ...

# %%
import pandas as pd
import numpy as np
import  statistics 
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller
import scipy.stats
import os
from arch.unitroot import ADF

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
 
from os import listdir
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#pathDaily = '/content/drive/My Drive/Colab Notebooks/Minute/'

PAIR_LIST=pd.read_csv("/content/drive/My Drive/Colab Notebooks/Combination_Basket.csv")
#PAIR_LIST=PAIR_LIST.head(100)
#d = {'stock1': ["FINCABLES"], 'stock2': ["KEI"]}
#PAIR_LIST=pd.DataFrame(data=d)

# %%
PAIR_LIST
# Out:
#          stock1      stock2
# 0    AUROPHARMA      BIOCON
# 1    AUROPHARMA    CADILAHC
# 2    AUROPHARMA       CIPLA
# 3    AUROPHARMA    DIVISLAB
# 4    AUROPHARMA     DRREDDY
# 5    AUROPHARMA    GLENMARK
# 6    AUROPHARMA       LUPIN
# 7    AUROPHARMA         PEL
# 8    AUROPHARMA   SUNPHARMA
# 9    AUROPHARMA  TORNTPHARM
# 10   AUROPHARMA  ABBOTINDIA
# 11   AUROPHARMA  AJANTPHARM
# 12   AUROPHARMA       ALKEM
# 13   AUROPHARMA  CAPLIPOINT
# 14   AUROPHARMA        ERIS
# 15   AUROPHARMA         FDC
# 16   AUROPHARMA  JBCHEPHARM
# 17   AUROPHARMA  NATCOPHARM
# 18   AUROPHARMA      PFIZER
# 19   AUROPHARMA        PGHL
# 20   AUROPHARMA     POLYMED
# 21   AUROPHARMA  UNICHEMLAB
# 22   AUROPHARMA  WOCKPHARMA
# 23       BIOCON    CADILAHC
# 24       BIOCON       CIPLA
# 25       BIOCON    DIVISLAB
# 26       BIOCON     DRREDDY
# 27       BIOCON    GLENMARK
# 28       BIOCON       LUPIN
# 29       BIOCON         PEL
# 30       BIOCON   SUNPHARMA
# 31       BIOCON  TORNTPHARM
# ...

# %%
trade_short = []
trade_long  = []
Train_collect = []
Test_collect = []


# !pip install yfinance
import yfinance as yf
nsedata = yf.Ticker("^NSEI")

import datetime
 
for pair in PAIR_LIST.index:
      try:

            nsedata = yf.Ticker(PAIR_LIST["stock1"][pair]+".NS")
            stock1 = nsedata.history(period="4mo",interval = "60m")
            stock1 = stock1[~stock1.index.duplicated(keep='first')]
            stock1=stock1.reindex(index=stock1.index[::-1])
            stock1["Time"]=stock1.index
            stock1.Time = pd.to_datetime(stock1.Time, format='%Y-%m-%d %H:%M')
            stock1 = stock1[['Time', 'Open', 'Close']]
            stock1.columns = ['Time', 'Stock1_Open', 'Stock1_Close']
            stock1["stock1"]=PAIR_LIST["stock1"][pair]
            #stock1["stock1_change"]=((((stock1["Stock1_Open"]-stock1["Stock1_Close"].shift(1))/stock1["Stock1_Open"]))*100)
            #stock1["stock1_change"]=((stock1['Stock1_Open']-stock1['Stock1_Close'])/stock1['Stock1_Close'])*100
            stock1["diff1"]=stock1["Stock1_Open"]-stock1["Stock1_Open"].shift(1)
            stock1["stock1_change"]=(((stock1["Stock1_Open"]-stock1["Stock1_Open"].shift(1))/stock1["Stock1_Open"]))*100
            

            nsedata = yf.Ticker(PAIR_LIST["stock2"][pair]+".NS")
            stock2 = nsedata.history(period="4mo",interval = "60m")
            stock2 = stock2[~stock2.index.duplicated(keep='first')]
            stock2=stock2.reindex(index=stock2.index[::-1])
            stock2.Time=stock2.index
            stock2["Time"] = pd.to_datetime(stock2.Time, format='%Y-%m-%d %H:%M')
            stock2 = stock2[['Time', 'Open', 'Close']]
            stock2.columns = ['Time', 'Stock2_Open', 'Stock2_Close']
            stock2["stock2"]=PAIR_LIST["stock2"][pair]
            #stock2["stock2_change"]=((((stock2["Stock2_Open"]-stock2["Stock2_Close"].shift(1))/stock2["Stock2_Open"]))*100)
            #stock2["stock2_change"]=((stock2['Stock2_Open']-stock2['Stock2_Close'])/stock2['Stock2_Close'])*100
            stock2["diff2"]=stock2["Stock2_Open"]-stock2["Stock2_Open"].shift(1)
            stock2["stock2_change"]=(((stock2["Stock2_Open"]-stock2["Stock2_Open"].shift(1))/stock2["Stock2_Open"]))*100

            merged = pd.merge(stock1, stock2, on='Time')
            merged['Spread']=(merged['stock1_change']) - merged['stock2_change']
            
            
            print(merged.head())
 
            mask = (merged['Time'] >= '2020-12-01') 
            #& (merged['Time'] < '2020-09-11')
            Train = merged.loc[mask]
            Train.loc[:,'Ratio'] = Train.Stock1_Close / Train.Stock2_Close
            
            sadf1 = np.diff(np.log(Train["Ratio"]))
            adf1 = ADF(sadf1)
            #print("{0:0.4f}".format(adf1.pvalue))


            nmask = (merged['Time'] > '2020-09-03') & (merged['Time'] < '2020-12-03') 
            #& (merged['Time'] < '2020-09-11')
            nTrain = merged.loc[nmask]
            
      #except Exception:
            if nTrain.empty:
              print("Empty")

            else:

              corr=scipy.stats.pearsonr(nTrain['Stock1_Close'], nTrain['Stock2_Close'])[0]
              score, pvalue, _ = coint(nTrain["Stock1_Close"],nTrain["Stock2_Close"])
      
              Train["dev1"]=Train["stock1_change"]-0
              Train["dev2"]=0-Train["stock2_change"]
              #Train["Signal"]=np.where((((Train["dev1"]>Train["dev2"])))&(Train["Spread"]>=2),"long",np.where((((Train["dev1"]<Train["dev2"])))&(Train["Spread"]>=2),"short","Notrade"))
              Train["Signal"]=np.where((((Train["stock1_change"]<Train["stock2_change"])))&(Train["Spread"]>=2),"long",np.where((((Train["stock1_change"]>Train["stock2_change"])))&(Train["Spread"]>=2),"short","Notrade"))
              Train["corr"]=corr
              #Train["ADF"]=adf1.pvalue
            

              #Train["Signal"]=np.where((Train["stock1_change"]>0)&(Train["stock2_change"]<=0)&(Train["Spread"]>4),"long",np.where((Train["stock2_change"]>0)&(Train["stock1_change"]<=0)&(Train["Spread"]>4),"short","Notrade"))
               #print(Train.head(10))
               #Train["Signakl"]=np.where(((Train["stock1_change"]>=4) & (Train.Time.dt.time < datetime.time(14, 15, 0))),"Entry","Exit") 
              if (corr>0.85):
                   if (adf1.pvalue<=0.05):
 
                     print("corr: ",corr)
                     print("pvalue: ",pvalue)
             
                #Test["long"]=np.where(Test["Spread_%"]>=2,1,0)
                #Test[Test["Spread_%"]>=2]
 
                     trade_long.append( Train[(( Train.Signal=="long")|( Train.Signal=="short") ) &( Train.Time.dt.time <= datetime.time(14, 15, 0))])
                                #(Train["Spread"]>=4) &( Train.Time.dt.time <= datetime.time(14, 15, 0)) & 
      finally:
                Test_collect.append(Train)
# Out:
# ...
#      |████████████████████████████████| 5.5MB 5.9MB/s
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.55-py2.py3-none-any.whl size=22615 sha256=10381d5b5d3079614b7f80b6c5cfaf6ee910087d19d3573a768966d472d16d91
#   Stored in directory: /root/.cache/pip/wheels/04/98/cc/2702a4242d60bdc14f48b4557c427ded1fe92aedf257d4565c
# Successfully built yfinance
# ...
#   Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:35: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
trade_long
# Out:
# [                        Time  Stock1_Open  Stock1_Close    stock1       diff1  \
#  77 2020-12-01 09:15:00+05:30  3764.699951        3611.0  DIVISLAB  153.649902
#
#      stock1_change  Stock2_Open  Stock2_Close stock2  diff2  stock2_change  \
#  77       4.081332  6406.350098        6813.0   PGHL -359.5       -5.61162
#
#        Spread     Ratio      dev1     dev2 Signal     corr
#  77  9.692952  0.530016  4.081332  5.61162  short  0.87015  ,
#                          Time  Stock1_Open  Stock1_Close stock1      diff1  \
#  42 2020-12-08 09:15:00+05:30   971.950012    952.450012  LUPIN  19.450012
#  49 2020-12-07 09:15:00+05:30   939.349976    945.349976  LUPIN  -5.950012
#
#      stock1_change  Stock2_Open  Stock2_Close      stock2      diff2  \
#  42       2.001133   520.049988    522.799988  CAPLIPOINT  -2.750000
#  49      -0.633418   494.950012    518.000000  CAPLIPOINT -22.599976
#
#      stock2_change    Spread     Ratio      dev1      dev2 Signal      corr
# ...

# %%
longt=pd.concat(trade_long)
longt.to_csv('trade_spread.csv')

# %%
from google.colab import files
files.download("trade_spread.csv")

# %%
trade_long[0].head(10)
# Out:
#                         Time  Stock1_Open  Stock1_Close    stock1       diff1  \
# 77 2020-12-01 09:15:00+05:30  3764.699951        3611.0  DIVISLAB  153.649902
#
#     stock1_change  Stock2_Open  Stock2_Close stock2  diff2  stock2_change  \
# 77       4.081332  6406.350098        6813.0   PGHL -359.5       -5.61162
#
#       Spread     Ratio      dev1     dev2 Signal     corr
# 77  9.692952  0.530016  4.081332  5.61162  short  0.87015
